# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.10.0'

# %%
tf.reset_default_graph()

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)

import tensorflow as tf

x = tf.placeholder(tf.float32, shape=[None, 784])
y_ = tf.placeholder(tf.float32, shape=[None, 10])
W = tf.Variable(tf.zeros([784,10]))
b = tf.Variable(tf.zeros([10]))

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)


def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],
                        strides=[1, 2, 2, 1], padding='SAME')

with tf.device('/gpu:0'):
    W_conv1 = weight_variable([5, 5, 1, 32])
    b_conv1 = bias_variable([32])
    x_image = tf.reshape(x, [-1, 28, 28, 1])
    h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
    h_pool1 = max_pool_2x2(h_conv1)

    W_conv2 = weight_variable([5, 5, 32, 64])
    b_conv2 = bias_variable([64])

    h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
    h_pool2 = max_pool_2x2(h_conv2)

    W_fc1 = weight_variable([7 * 7 * 64, 1024])
    b_fc1 = bias_variable([1024])
    
    
    h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
    h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

    keep_prob = tf.placeholder(tf.float32)
    h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

    W_fc2 = weight_variable([1024, 10])
    b_fc2 = bias_variable([10])

    y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

    
    cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
    train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
    correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    with tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)) as sess:
        sess.run(tf.global_variables_initializer())
        for i in range(1000):
            batch = mnist.train.next_batch(50)
            if i % 100 == 0:
                train_accuracy = accuracy.eval(feed_dict={
                                                        x: batch[0], y_: batch[1], keep_prob: 1.0})
            print('step %d, training accuracy %g' % (i, train_accuracy))
            train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})
            
            
            
     
        print('test accuracy %g' % accuracy.eval(feed_dict={
                  x: mnist.test.images[:100], y_: mnist.test.labels[:100], keep_prob: 1.0}))
      
        
        """
        
        메모리 부족 발생해서 테스트는 줄여서 처리함
        
        print('test accuracy %g' % accuracy.eval(feed_dict={
                  x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
        """
# Out:
# WARNING:tensorflow:From <ipython-input-4-b7c7a02bd050>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From C:\Users\John\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From C:\Users\John\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\Users\John\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data\train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\John\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data\t10k-images-idx3-ubyte.gz
# Extracting MNIST_data\t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\Users\John\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From <ipython-input-4-b7c7a02bd050>:56: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.
#
# step 0, training accuracy 0.06
# step 1, training accuracy 0.06
# step 2, training accuracy 0.06
# step 3, training accuracy 0.06
# step 4, training accuracy 0.06
# step 5, training accuracy 0.06
# step 6, training accuracy 0.06
# step 7, training accuracy 0.06
# step 8, training accuracy 0.06
# step 9, training accuracy 0.06
# step 10, training accuracy 0.06
# step 11, training accuracy 0.06
# step 12, training accuracy 0.06
# step 13, training accuracy 0.06
# step 14, training accuracy 0.06
# step 15, training accuracy 0.06
# step 16, training accuracy 0.06
# step 17, training accuracy 0.06
# step 18, training accuracy 0.06
# step 19, training accuracy 0.06
# step 20, training accuracy 0.06
# step 21, training accuracy 0.06
# step 22, training accuracy 0.06
# step 23, training accuracy 0.06
# step 24, training accuracy 0.06
# step 25, training accuracy 0.06
# step 26, training accuracy 0.06
# step 27, training accuracy 0.06
# step 28, training accuracy 0.06
# step 29, training accuracy 0.06
# step 30, training accuracy 0.06
# step 31, training accuracy 0.06
# step 32, training accuracy 0.06
# step 33, training accuracy 0.06
# step 34, training accuracy 0.06
# step 35, training accuracy 0.06
# step 36, training accuracy 0.06
# step 37, training accuracy 0.06
# step 38, training accuracy 0.06
# step 39, training accuracy 0.06
# step 40, training accuracy 0.06
# step 41, training accuracy 0.06
# step 42, training accuracy 0.06
# step 43, training accuracy 0.06
# step 44, training accuracy 0.06
# step 45, training accuracy 0.06
# step 46, training accuracy 0.06
# step 47, training accuracy 0.06
# step 48, training accuracy 0.06
# step 49, training accuracy 0.06
# step 50, training accuracy 0.06
# step 51, training accuracy 0.06
# step 52, training accuracy 0.06
# step 53, training accuracy 0.06
# step 54, training accuracy 0.06
# step 55, training accuracy 0.06
# step 56, training accuracy 0.06
# step 57, training accuracy 0.06
# step 58, training accuracy 0.06
# step 59, training accuracy 0.06
# step 60, training accuracy 0.06
# step 61, training accuracy 0.06
# step 62, training accuracy 0.06
# step 63, training accuracy 0.06
# step 64, training accuracy 0.06
# step 65, training accuracy 0.06
# step 66, training accuracy 0.06
# step 67, training accuracy 0.06
# step 68, training accuracy 0.06
# step 69, training accuracy 0.06
# step 70, training accuracy 0.06
# step 71, training accuracy 0.06
# step 72, training accuracy 0.06
# step 73, training accuracy 0.06
# step 74, training accuracy 0.06
# step 75, training accuracy 0.06
# step 76, training accuracy 0.06
# step 77, training accuracy 0.06
# step 78, training accuracy 0.06
# step 79, training accuracy 0.06
# step 80, training accuracy 0.06
# step 81, training accuracy 0.06
# step 82, training accuracy 0.06
# step 83, training accuracy 0.06
# step 84, training accuracy 0.06
# step 85, training accuracy 0.06
# step 86, training accuracy 0.06
# step 87, training accuracy 0.06
# step 88, training accuracy 0.06
# step 89, training accuracy 0.06
# step 90, training accuracy 0.06
# step 91, training accuracy 0.06
# step 92, training accuracy 0.06
# step 93, training accuracy 0.06
# step 94, training accuracy 0.06
# step 95, training accuracy 0.06
# step 96, training accuracy 0.06
# step 97, training accuracy 0.06
# step 98, training accuracy 0.06
# step 99, training accuracy 0.06
# step 100, training accuracy 0.8
# step 101, training accuracy 0.8
# step 102, training accuracy 0.8
# step 103, training accuracy 0.8
# step 104, training accuracy 0.8
# step 105, training accuracy 0.8
# step 106, training accuracy 0.8
# step 107, training accuracy 0.8
# step 108, training accuracy 0.8
# step 109, training accuracy 0.8
# step 110, training accuracy 0.8
# step 111, training accuracy 0.8
# step 112, training accuracy 0.8
# step 113, training accuracy 0.8
# step 114, training accuracy 0.8
# step 115, training accuracy 0.8
# step 116, training accuracy 0.8
# step 117, training accuracy 0.8
# step 118, training accuracy 0.8
# step 119, training accuracy 0.8
# step 120, training accuracy 0.8
# step 121, training accuracy 0.8
# step 122, training accuracy 0.8
# step 123, training accuracy 0.8
# step 124, training accuracy 0.8
# step 125, training accuracy 0.8
# step 126, training accuracy 0.8
# step 127, training accuracy 0.8
# step 128, training accuracy 0.8
# step 129, training accuracy 0.8
# step 130, training accuracy 0.8
# step 131, training accuracy 0.8
# step 132, training accuracy 0.8
# step 133, training accuracy 0.8
# step 134, training accuracy 0.8
# step 135, training accuracy 0.8
# step 136, training accuracy 0.8
# step 137, training accuracy 0.8
# step 138, training accuracy 0.8
# step 139, training accuracy 0.8
# step 140, training accuracy 0.8
# step 141, training accuracy 0.8
# step 142, training accuracy 0.8
# step 143, training accuracy 0.8
# step 144, training accuracy 0.8
# step 145, training accuracy 0.8
# step 146, training accuracy 0.8
# step 147, training accuracy 0.8
# step 148, training accuracy 0.8
# step 149, training accuracy 0.8
# step 150, training accuracy 0.8
# step 151, training accuracy 0.8
# step 152, training accuracy 0.8
# step 153, training accuracy 0.8
# step 154, training accuracy 0.8
# step 155, training accuracy 0.8
# step 156, training accuracy 0.8
# step 157, training accuracy 0.8
# step 158, training accuracy 0.8
# step 159, training accuracy 0.8
# step 160, training accuracy 0.8
# step 161, training accuracy 0.8
# step 162, training accuracy 0.8
# step 163, training accuracy 0.8
# step 164, training accuracy 0.8
# step 165, training accuracy 0.8
# step 166, training accuracy 0.8
# step 167, training accuracy 0.8
# step 168, training accuracy 0.8
# step 169, training accuracy 0.8
# step 170, training accuracy 0.8
# step 171, training accuracy 0.8
# step 172, training accuracy 0.8
# step 173, training accuracy 0.8
# step 174, training accuracy 0.8
# step 175, training accuracy 0.8
# step 176, training accuracy 0.8
# step 177, training accuracy 0.8
# step 178, training accuracy 0.8
# step 179, training accuracy 0.8
# step 180, training accuracy 0.8
# step 181, training accuracy 0.8
# step 182, training accuracy 0.8
# step 183, training accuracy 0.8
# step 184, training accuracy 0.8
# step 185, training accuracy 0.8
# step 186, training accuracy 0.8
# step 187, training accuracy 0.8
# step 188, training accuracy 0.8
# step 189, training accuracy 0.8
# step 190, training accuracy 0.8
# step 191, training accuracy 0.8
# step 192, training accuracy 0.8
# step 193, training accuracy 0.8
# step 194, training accuracy 0.8
# step 195, training accuracy 0.8
# step 196, training accuracy 0.8
# step 197, training accuracy 0.8
# step 198, training accuracy 0.8
# step 199, training accuracy 0.8
# step 200, training accuracy 0.88
# step 201, training accuracy 0.88
# step 202, training accuracy 0.88
# step 203, training accuracy 0.88
# step 204, training accuracy 0.88
# step 205, training accuracy 0.88
# step 206, training accuracy 0.88
# step 207, training accuracy 0.88
# step 208, training accuracy 0.88
# step 209, training accuracy 0.88
# step 210, training accuracy 0.88
# step 211, training accuracy 0.88
# step 212, training accuracy 0.88
# step 213, training accuracy 0.88
# step 214, training accuracy 0.88
# step 215, training accuracy 0.88
# step 216, training accuracy 0.88
# step 217, training accuracy 0.88
# step 218, training accuracy 0.88
# step 219, training accuracy 0.88
# step 220, training accuracy 0.88
# step 221, training accuracy 0.88
# step 222, training accuracy 0.88
# step 223, training accuracy 0.88
# step 224, training accuracy 0.88
# step 225, training accuracy 0.88
# step 226, training accuracy 0.88
# step 227, training accuracy 0.88
# step 228, training accuracy 0.88
# step 229, training accuracy 0.88
# step 230, training accuracy 0.88
# step 231, training accuracy 0.88
# step 232, training accuracy 0.88
# step 233, training accuracy 0.88
# step 234, training accuracy 0.88
# step 235, training accuracy 0.88
# step 236, training accuracy 0.88
# step 237, training accuracy 0.88
# step 238, training accuracy 0.88
# step 239, training accuracy 0.88
# step 240, training accuracy 0.88
# step 241, training accuracy 0.88
# step 242, training accuracy 0.88
# step 243, training accuracy 0.88
# step 244, training accuracy 0.88
# step 245, training accuracy 0.88
# step 246, training accuracy 0.88
# step 247, training accuracy 0.88
# step 248, training accuracy 0.88
# step 249, training accuracy 0.88
# step 250, training accuracy 0.88
# step 251, training accuracy 0.88
# step 252, training accuracy 0.88
# step 253, training accuracy 0.88
# step 254, training accuracy 0.88
# step 255, training accuracy 0.88
# step 256, training accuracy 0.88
# step 257, training accuracy 0.88
# step 258, training accuracy 0.88
# step 259, training accuracy 0.88
# step 260, training accuracy 0.88
# step 261, training accuracy 0.88
# step 262, training accuracy 0.88
# step 263, training accuracy 0.88
# step 264, training accuracy 0.88
# step 265, training accuracy 0.88
# step 266, training accuracy 0.88
# step 267, training accuracy 0.88
# step 268, training accuracy 0.88
# step 269, training accuracy 0.88
# step 270, training accuracy 0.88
# step 271, training accuracy 0.88
# step 272, training accuracy 0.88
# step 273, training accuracy 0.88
# step 274, training accuracy 0.88
# step 275, training accuracy 0.88
# step 276, training accuracy 0.88
# step 277, training accuracy 0.88
# step 278, training accuracy 0.88
# step 279, training accuracy 0.88
# step 280, training accuracy 0.88
# step 281, training accuracy 0.88
# step 282, training accuracy 0.88
# step 283, training accuracy 0.88
# step 284, training accuracy 0.88
# step 285, training accuracy 0.88
# step 286, training accuracy 0.88
# step 287, training accuracy 0.88
# step 288, training accuracy 0.88
# step 289, training accuracy 0.88
# step 290, training accuracy 0.88
# step 291, training accuracy 0.88
# step 292, training accuracy 0.88
# step 293, training accuracy 0.88
# step 294, training accuracy 0.88
# step 295, training accuracy 0.88
# step 296, training accuracy 0.88
# step 297, training accuracy 0.88
# step 298, training accuracy 0.88
# step 299, training accuracy 0.88
# step 300, training accuracy 0.94
# step 301, training accuracy 0.94
# step 302, training accuracy 0.94
# step 303, training accuracy 0.94
# step 304, training accuracy 0.94
# step 305, training accuracy 0.94
# step 306, training accuracy 0.94
# step 307, training accuracy 0.94
# step 308, training accuracy 0.94
# step 309, training accuracy 0.94
# step 310, training accuracy 0.94
# step 311, training accuracy 0.94
# step 312, training accuracy 0.94
# step 313, training accuracy 0.94
# step 314, training accuracy 0.94
# step 315, training accuracy 0.94
# step 316, training accuracy 0.94
# step 317, training accuracy 0.94
# step 318, training accuracy 0.94
# step 319, training accuracy 0.94
# step 320, training accuracy 0.94
# step 321, training accuracy 0.94
# step 322, training accuracy 0.94
# step 323, training accuracy 0.94
# step 324, training accuracy 0.94
# step 325, training accuracy 0.94
# step 326, training accuracy 0.94
# step 327, training accuracy 0.94
# step 328, training accuracy 0.94
# step 329, training accuracy 0.94
# step 330, training accuracy 0.94
# step 331, training accuracy 0.94
# step 332, training accuracy 0.94
# step 333, training accuracy 0.94
# step 334, training accuracy 0.94
# step 335, training accuracy 0.94
# step 336, training accuracy 0.94
# step 337, training accuracy 0.94
# step 338, training accuracy 0.94
# step 339, training accuracy 0.94
# step 340, training accuracy 0.94
# step 341, training accuracy 0.94
# step 342, training accuracy 0.94
# step 343, training accuracy 0.94
# step 344, training accuracy 0.94
# step 345, training accuracy 0.94
# step 346, training accuracy 0.94
# step 347, training accuracy 0.94
# step 348, training accuracy 0.94
# step 349, training accuracy 0.94
# step 350, training accuracy 0.94
# step 351, training accuracy 0.94
# step 352, training accuracy 0.94
# step 353, training accuracy 0.94
# step 354, training accuracy 0.94
# step 355, training accuracy 0.94
# step 356, training accuracy 0.94
# step 357, training accuracy 0.94
# step 358, training accuracy 0.94
# step 359, training accuracy 0.94
# step 360, training accuracy 0.94
# step 361, training accuracy 0.94
# step 362, training accuracy 0.94
# step 363, training accuracy 0.94
# step 364, training accuracy 0.94
# step 365, training accuracy 0.94
# step 366, training accuracy 0.94
# step 367, training accuracy 0.94
# step 368, training accuracy 0.94
# step 369, training accuracy 0.94
# step 370, training accuracy 0.94
# step 371, training accuracy 0.94
# step 372, training accuracy 0.94
# step 373, training accuracy 0.94
# step 374, training accuracy 0.94
# step 375, training accuracy 0.94
# step 376, training accuracy 0.94
# step 377, training accuracy 0.94
# step 378, training accuracy 0.94
# step 379, training accuracy 0.94
# step 380, training accuracy 0.94
# step 381, training accuracy 0.94
# step 382, training accuracy 0.94
# step 383, training accuracy 0.94
# step 384, training accuracy 0.94
# step 385, training accuracy 0.94
# step 386, training accuracy 0.94
# step 387, training accuracy 0.94
# step 388, training accuracy 0.94
# step 389, training accuracy 0.94
# step 390, training accuracy 0.94
# step 391, training accuracy 0.94
# step 392, training accuracy 0.94
# step 393, training accuracy 0.94
# step 394, training accuracy 0.94
# step 395, training accuracy 0.94
# step 396, training accuracy 0.94
# step 397, training accuracy 0.94
# step 398, training accuracy 0.94
# step 399, training accuracy 0.94
# step 400, training accuracy 0.88
# step 401, training accuracy 0.88
# step 402, training accuracy 0.88
# step 403, training accuracy 0.88
# step 404, training accuracy 0.88
# step 405, training accuracy 0.88
# step 406, training accuracy 0.88
# step 407, training accuracy 0.88
# step 408, training accuracy 0.88
# step 409, training accuracy 0.88
# step 410, training accuracy 0.88
# step 411, training accuracy 0.88
# step 412, training accuracy 0.88
# step 413, training accuracy 0.88
# step 414, training accuracy 0.88
# step 415, training accuracy 0.88
# step 416, training accuracy 0.88
# step 417, training accuracy 0.88
# step 418, training accuracy 0.88
# step 419, training accuracy 0.88
# step 420, training accuracy 0.88
# step 421, training accuracy 0.88
# step 422, training accuracy 0.88
# step 423, training accuracy 0.88
# step 424, training accuracy 0.88
# step 425, training accuracy 0.88
# step 426, training accuracy 0.88
# step 427, training accuracy 0.88
# step 428, training accuracy 0.88
# step 429, training accuracy 0.88
# step 430, training accuracy 0.88
# step 431, training accuracy 0.88
# step 432, training accuracy 0.88
# step 433, training accuracy 0.88
# step 434, training accuracy 0.88
# step 435, training accuracy 0.88
# step 436, training accuracy 0.88
# step 437, training accuracy 0.88
# step 438, training accuracy 0.88
# step 439, training accuracy 0.88
# step 440, training accuracy 0.88
# step 441, training accuracy 0.88
# step 442, training accuracy 0.88
# step 443, training accuracy 0.88
# step 444, training accuracy 0.88
# step 445, training accuracy 0.88
# step 446, training accuracy 0.88
# step 447, training accuracy 0.88
# step 448, training accuracy 0.88
# step 449, training accuracy 0.88
# step 450, training accuracy 0.88
# step 451, training accuracy 0.88
# step 452, training accuracy 0.88
# step 453, training accuracy 0.88
# step 454, training accuracy 0.88
# step 455, training accuracy 0.88
# step 456, training accuracy 0.88
# step 457, training accuracy 0.88
# step 458, training accuracy 0.88
# step 459, training accuracy 0.88
# step 460, training accuracy 0.88
# step 461, training accuracy 0.88
# step 462, training accuracy 0.88
# step 463, training accuracy 0.88
# step 464, training accuracy 0.88
# step 465, training accuracy 0.88
# step 466, training accuracy 0.88
# step 467, training accuracy 0.88
# step 468, training accuracy 0.88
# step 469, training accuracy 0.88
# step 470, training accuracy 0.88
# step 471, training accuracy 0.88
# step 472, training accuracy 0.88
# step 473, training accuracy 0.88
# step 474, training accuracy 0.88
# step 475, training accuracy 0.88
# step 476, training accuracy 0.88
# step 477, training accuracy 0.88
# step 478, training accuracy 0.88
# step 479, training accuracy 0.88
# step 480, training accuracy 0.88
# step 481, training accuracy 0.88
# step 482, training accuracy 0.88
# step 483, training accuracy 0.88
# step 484, training accuracy 0.88
# step 485, training accuracy 0.88
# step 486, training accuracy 0.88
# step 487, training accuracy 0.88
# step 488, training accuracy 0.88
# step 489, training accuracy 0.88
# step 490, training accuracy 0.88
# step 491, training accuracy 0.88
# step 492, training accuracy 0.88
# step 493, training accuracy 0.88
# step 494, training accuracy 0.88
# step 495, training accuracy 0.88
# step 496, training accuracy 0.88
# step 497, training accuracy 0.88
# step 498, training accuracy 0.88
# step 499, training accuracy 0.88
# step 500, training accuracy 0.88
# step 501, training accuracy 0.88
# step 502, training accuracy 0.88
# step 503, training accuracy 0.88
# step 504, training accuracy 0.88
# step 505, training accuracy 0.88
# step 506, training accuracy 0.88
# step 507, training accuracy 0.88
# step 508, training accuracy 0.88
# step 509, training accuracy 0.88
# step 510, training accuracy 0.88
# step 511, training accuracy 0.88
# step 512, training accuracy 0.88
# step 513, training accuracy 0.88
# step 514, training accuracy 0.88
# step 515, training accuracy 0.88
# step 516, training accuracy 0.88
# step 517, training accuracy 0.88
# step 518, training accuracy 0.88
# step 519, training accuracy 0.88
# step 520, training accuracy 0.88
# step 521, training accuracy 0.88
# step 522, training accuracy 0.88
# step 523, training accuracy 0.88
# step 524, training accuracy 0.88
# step 525, training accuracy 0.88
# step 526, training accuracy 0.88
# step 527, training accuracy 0.88
# step 528, training accuracy 0.88
# step 529, training accuracy 0.88
# step 530, training accuracy 0.88
# step 531, training accuracy 0.88
# step 532, training accuracy 0.88
# step 533, training accuracy 0.88
# step 534, training accuracy 0.88
# step 535, training accuracy 0.88
# step 536, training accuracy 0.88
# step 537, training accuracy 0.88
# step 538, training accuracy 0.88
# step 539, training accuracy 0.88
# step 540, training accuracy 0.88
# step 541, training accuracy 0.88
# step 542, training accuracy 0.88
# step 543, training accuracy 0.88
# step 544, training accuracy 0.88
# step 545, training accuracy 0.88
# step 546, training accuracy 0.88
# step 547, training accuracy 0.88
# step 548, training accuracy 0.88
# step 549, training accuracy 0.88
# step 550, training accuracy 0.88
# step 551, training accuracy 0.88
# step 552, training accuracy 0.88
# step 553, training accuracy 0.88
# step 554, training accuracy 0.88
# step 555, training accuracy 0.88
# step 556, training accuracy 0.88
# step 557, training accuracy 0.88
# step 558, training accuracy 0.88
# step 559, training accuracy 0.88
# step 560, training accuracy 0.88
# step 561, training accuracy 0.88
# step 562, training accuracy 0.88
# step 563, training accuracy 0.88
# step 564, training accuracy 0.88
# step 565, training accuracy 0.88
# step 566, training accuracy 0.88
# step 567, training accuracy 0.88
# step 568, training accuracy 0.88
# step 569, training accuracy 0.88
# step 570, training accuracy 0.88
# step 571, training accuracy 0.88
# step 572, training accuracy 0.88
# step 573, training accuracy 0.88
# step 574, training accuracy 0.88
# step 575, training accuracy 0.88
# step 576, training accuracy 0.88
# step 577, training accuracy 0.88
# step 578, training accuracy 0.88
# step 579, training accuracy 0.88
# step 580, training accuracy 0.88
# step 581, training accuracy 0.88
# step 582, training accuracy 0.88
# step 583, training accuracy 0.88
# step 584, training accuracy 0.88
# step 585, training accuracy 0.88
# step 586, training accuracy 0.88
# step 587, training accuracy 0.88
# step 588, training accuracy 0.88
# step 589, training accuracy 0.88
# step 590, training accuracy 0.88
# step 591, training accuracy 0.88
# step 592, training accuracy 0.88
# step 593, training accuracy 0.88
# step 594, training accuracy 0.88
# step 595, training accuracy 0.88
# step 596, training accuracy 0.88
# step 597, training accuracy 0.88
# step 598, training accuracy 0.88
# step 599, training accuracy 0.88
# step 600, training accuracy 0.94
# step 601, training accuracy 0.94
# step 602, training accuracy 0.94
# step 603, training accuracy 0.94
# step 604, training accuracy 0.94
# step 605, training accuracy 0.94
# step 606, training accuracy 0.94
# step 607, training accuracy 0.94
# step 608, training accuracy 0.94
# step 609, training accuracy 0.94
# step 610, training accuracy 0.94
# step 611, training accuracy 0.94
# step 612, training accuracy 0.94
# step 613, training accuracy 0.94
# step 614, training accuracy 0.94
# step 615, training accuracy 0.94
# step 616, training accuracy 0.94
# step 617, training accuracy 0.94
# step 618, training accuracy 0.94
# step 619, training accuracy 0.94
# step 620, training accuracy 0.94
# step 621, training accuracy 0.94
# step 622, training accuracy 0.94
# step 623, training accuracy 0.94
# step 624, training accuracy 0.94
# step 625, training accuracy 0.94
# step 626, training accuracy 0.94
# step 627, training accuracy 0.94
# step 628, training accuracy 0.94
# step 629, training accuracy 0.94
# step 630, training accuracy 0.94
# step 631, training accuracy 0.94
# step 632, training accuracy 0.94
# step 633, training accuracy 0.94
# step 634, training accuracy 0.94
# step 635, training accuracy 0.94
# step 636, training accuracy 0.94
# step 637, training accuracy 0.94
# step 638, training accuracy 0.94
# step 639, training accuracy 0.94
# step 640, training accuracy 0.94
# step 641, training accuracy 0.94
# step 642, training accuracy 0.94
# step 643, training accuracy 0.94
# step 644, training accuracy 0.94
# step 645, training accuracy 0.94
# step 646, training accuracy 0.94
# step 647, training accuracy 0.94
# step 648, training accuracy 0.94
# step 649, training accuracy 0.94
# step 650, training accuracy 0.94
# step 651, training accuracy 0.94
# step 652, training accuracy 0.94
# step 653, training accuracy 0.94
# step 654, training accuracy 0.94
# step 655, training accuracy 0.94
# step 656, training accuracy 0.94
# step 657, training accuracy 0.94
# step 658, training accuracy 0.94
# step 659, training accuracy 0.94
# step 660, training accuracy 0.94
# step 661, training accuracy 0.94
# step 662, training accuracy 0.94
# step 663, training accuracy 0.94
# step 664, training accuracy 0.94
# step 665, training accuracy 0.94
# step 666, training accuracy 0.94
# step 667, training accuracy 0.94
# step 668, training accuracy 0.94
# step 669, training accuracy 0.94
# step 670, training accuracy 0.94
# step 671, training accuracy 0.94
# step 672, training accuracy 0.94
# step 673, training accuracy 0.94
# step 674, training accuracy 0.94
# step 675, training accuracy 0.94
# step 676, training accuracy 0.94
# step 677, training accuracy 0.94
# step 678, training accuracy 0.94
# step 679, training accuracy 0.94
# step 680, training accuracy 0.94
# step 681, training accuracy 0.94
# step 682, training accuracy 0.94
# step 683, training accuracy 0.94
# step 684, training accuracy 0.94
# step 685, training accuracy 0.94
# step 686, training accuracy 0.94
# step 687, training accuracy 0.94
# step 688, training accuracy 0.94
# step 689, training accuracy 0.94
# step 690, training accuracy 0.94
# step 691, training accuracy 0.94
# step 692, training accuracy 0.94
# step 693, training accuracy 0.94
# step 694, training accuracy 0.94
# step 695, training accuracy 0.94
# step 696, training accuracy 0.94
# step 697, training accuracy 0.94
# step 698, training accuracy 0.94
# step 699, training accuracy 0.94
# step 700, training accuracy 0.96
# step 701, training accuracy 0.96
# step 702, training accuracy 0.96
# step 703, training accuracy 0.96
# step 704, training accuracy 0.96
# step 705, training accuracy 0.96
# step 706, training accuracy 0.96
# step 707, training accuracy 0.96
# step 708, training accuracy 0.96
# step 709, training accuracy 0.96
# step 710, training accuracy 0.96
# step 711, training accuracy 0.96
# step 712, training accuracy 0.96
# step 713, training accuracy 0.96
# step 714, training accuracy 0.96
# step 715, training accuracy 0.96
# step 716, training accuracy 0.96
# step 717, training accuracy 0.96
# step 718, training accuracy 0.96
# step 719, training accuracy 0.96
# step 720, training accuracy 0.96
# step 721, training accuracy 0.96
# step 722, training accuracy 0.96
# step 723, training accuracy 0.96
# step 724, training accuracy 0.96
# step 725, training accuracy 0.96
# step 726, training accuracy 0.96
# step 727, training accuracy 0.96
# step 728, training accuracy 0.96
# step 729, training accuracy 0.96
# step 730, training accuracy 0.96
# step 731, training accuracy 0.96
# step 732, training accuracy 0.96
# step 733, training accuracy 0.96
# step 734, training accuracy 0.96
# step 735, training accuracy 0.96
# step 736, training accuracy 0.96
# step 737, training accuracy 0.96
# step 738, training accuracy 0.96
# step 739, training accuracy 0.96
# step 740, training accuracy 0.96
# step 741, training accuracy 0.96
# step 742, training accuracy 0.96
# step 743, training accuracy 0.96
# step 744, training accuracy 0.96
# step 745, training accuracy 0.96
# step 746, training accuracy 0.96
# step 747, training accuracy 0.96
# step 748, training accuracy 0.96
# step 749, training accuracy 0.96
# step 750, training accuracy 0.96
# step 751, training accuracy 0.96
# step 752, training accuracy 0.96
# step 753, training accuracy 0.96
# step 754, training accuracy 0.96
# step 755, training accuracy 0.96
# step 756, training accuracy 0.96
# step 757, training accuracy 0.96
# step 758, training accuracy 0.96
# step 759, training accuracy 0.96
# step 760, training accuracy 0.96
# step 761, training accuracy 0.96
# step 762, training accuracy 0.96
# step 763, training accuracy 0.96
# step 764, training accuracy 0.96
# step 765, training accuracy 0.96
# step 766, training accuracy 0.96
# step 767, training accuracy 0.96
# step 768, training accuracy 0.96
# step 769, training accuracy 0.96
# step 770, training accuracy 0.96
# step 771, training accuracy 0.96
# step 772, training accuracy 0.96
# step 773, training accuracy 0.96
# step 774, training accuracy 0.96
# step 775, training accuracy 0.96
# step 776, training accuracy 0.96
# step 777, training accuracy 0.96
# step 778, training accuracy 0.96
# step 779, training accuracy 0.96
# step 780, training accuracy 0.96
# step 781, training accuracy 0.96
# step 782, training accuracy 0.96
# step 783, training accuracy 0.96
# step 784, training accuracy 0.96
# step 785, training accuracy 0.96
# step 786, training accuracy 0.96
# step 787, training accuracy 0.96
# step 788, training accuracy 0.96
# step 789, training accuracy 0.96
# step 790, training accuracy 0.96
# step 791, training accuracy 0.96
# step 792, training accuracy 0.96
# step 793, training accuracy 0.96
# step 794, training accuracy 0.96
# step 795, training accuracy 0.96
# step 796, training accuracy 0.96
# step 797, training accuracy 0.96
# step 798, training accuracy 0.96
# step 799, training accuracy 0.96
# step 800, training accuracy 0.98
# step 801, training accuracy 0.98
# step 802, training accuracy 0.98
# step 803, training accuracy 0.98
# step 804, training accuracy 0.98
# step 805, training accuracy 0.98
# step 806, training accuracy 0.98
# step 807, training accuracy 0.98
# step 808, training accuracy 0.98
# step 809, training accuracy 0.98
# step 810, training accuracy 0.98
# step 811, training accuracy 0.98
# step 812, training accuracy 0.98
# step 813, training accuracy 0.98
# step 814, training accuracy 0.98
# step 815, training accuracy 0.98
# step 816, training accuracy 0.98
# step 817, training accuracy 0.98
# step 818, training accuracy 0.98
# step 819, training accuracy 0.98
# step 820, training accuracy 0.98
# step 821, training accuracy 0.98
# step 822, training accuracy 0.98
# step 823, training accuracy 0.98
# step 824, training accuracy 0.98
# step 825, training accuracy 0.98
# step 826, training accuracy 0.98
# step 827, training accuracy 0.98
# step 828, training accuracy 0.98
# step 829, training accuracy 0.98
# step 830, training accuracy 0.98
# step 831, training accuracy 0.98
# step 832, training accuracy 0.98
# step 833, training accuracy 0.98
# step 834, training accuracy 0.98
# step 835, training accuracy 0.98
# step 836, training accuracy 0.98
# step 837, training accuracy 0.98
# step 838, training accuracy 0.98
# step 839, training accuracy 0.98
# step 840, training accuracy 0.98
# step 841, training accuracy 0.98
# step 842, training accuracy 0.98
# step 843, training accuracy 0.98
# step 844, training accuracy 0.98
# step 845, training accuracy 0.98
# step 846, training accuracy 0.98
# step 847, training accuracy 0.98
# step 848, training accuracy 0.98
# step 849, training accuracy 0.98
# step 850, training accuracy 0.98
# step 851, training accuracy 0.98
# step 852, training accuracy 0.98
# step 853, training accuracy 0.98
# step 854, training accuracy 0.98
# step 855, training accuracy 0.98
# step 856, training accuracy 0.98
# step 857, training accuracy 0.98
# step 858, training accuracy 0.98
# step 859, training accuracy 0.98
# step 860, training accuracy 0.98
# step 861, training accuracy 0.98
# step 862, training accuracy 0.98
# step 863, training accuracy 0.98
# step 864, training accuracy 0.98
# step 865, training accuracy 0.98
# step 866, training accuracy 0.98
# step 867, training accuracy 0.98
# step 868, training accuracy 0.98
# step 869, training accuracy 0.98
# step 870, training accuracy 0.98
# step 871, training accuracy 0.98
# step 872, training accuracy 0.98
# step 873, training accuracy 0.98
# step 874, training accuracy 0.98
# step 875, training accuracy 0.98
# step 876, training accuracy 0.98
# step 877, training accuracy 0.98
# step 878, training accuracy 0.98
# step 879, training accuracy 0.98
# step 880, training accuracy 0.98
# step 881, training accuracy 0.98
# step 882, training accuracy 0.98
# step 883, training accuracy 0.98
# step 884, training accuracy 0.98
# step 885, training accuracy 0.98
# step 886, training accuracy 0.98
# step 887, training accuracy 0.98
# step 888, training accuracy 0.98
# step 889, training accuracy 0.98
# step 890, training accuracy 0.98
# step 891, training accuracy 0.98
# step 892, training accuracy 0.98
# step 893, training accuracy 0.98
# step 894, training accuracy 0.98
# step 895, training accuracy 0.98
# step 896, training accuracy 0.98
# step 897, training accuracy 0.98
# step 898, training accuracy 0.98
# step 899, training accuracy 0.98
# step 900, training accuracy 0.98
# step 901, training accuracy 0.98
# step 902, training accuracy 0.98
# step 903, training accuracy 0.98
# step 904, training accuracy 0.98
# step 905, training accuracy 0.98
# step 906, training accuracy 0.98
# step 907, training accuracy 0.98
# step 908, training accuracy 0.98
# step 909, training accuracy 0.98
# step 910, training accuracy 0.98
# step 911, training accuracy 0.98
# step 912, training accuracy 0.98
# step 913, training accuracy 0.98
# step 914, training accuracy 0.98
# step 915, training accuracy 0.98
# step 916, training accuracy 0.98
# step 917, training accuracy 0.98
# step 918, training accuracy 0.98
# step 919, training accuracy 0.98
# step 920, training accuracy 0.98
# step 921, training accuracy 0.98
# step 922, training accuracy 0.98
# step 923, training accuracy 0.98
# step 924, training accuracy 0.98
# step 925, training accuracy 0.98
# step 926, training accuracy 0.98
# step 927, training accuracy 0.98
# step 928, training accuracy 0.98
# step 929, training accuracy 0.98
# step 930, training accuracy 0.98
# step 931, training accuracy 0.98
# step 932, training accuracy 0.98
# step 933, training accuracy 0.98
# step 934, training accuracy 0.98
# step 935, training accuracy 0.98
# step 936, training accuracy 0.98
# step 937, training accuracy 0.98
# step 938, training accuracy 0.98
# step 939, training accuracy 0.98
# step 940, training accuracy 0.98
# step 941, training accuracy 0.98
# step 942, training accuracy 0.98
# step 943, training accuracy 0.98
# step 944, training accuracy 0.98
# step 945, training accuracy 0.98
# step 946, training accuracy 0.98
# step 947, training accuracy 0.98
# step 948, training accuracy 0.98
# step 949, training accuracy 0.98
# step 950, training accuracy 0.98
# step 951, training accuracy 0.98
# step 952, training accuracy 0.98
# step 953, training accuracy 0.98
# step 954, training accuracy 0.98
# step 955, training accuracy 0.98
# step 956, training accuracy 0.98
# step 957, training accuracy 0.98
# step 958, training accuracy 0.98
# step 959, training accuracy 0.98
# step 960, training accuracy 0.98
# step 961, training accuracy 0.98
# step 962, training accuracy 0.98
# step 963, training accuracy 0.98
# step 964, training accuracy 0.98
# step 965, training accuracy 0.98
# step 966, training accuracy 0.98
# step 967, training accuracy 0.98
# step 968, training accuracy 0.98
# step 969, training accuracy 0.98
# step 970, training accuracy 0.98
# step 971, training accuracy 0.98
# step 972, training accuracy 0.98
# step 973, training accuracy 0.98
# step 974, training accuracy 0.98
# step 975, training accuracy 0.98
# step 976, training accuracy 0.98
# step 977, training accuracy 0.98
# step 978, training accuracy 0.98
# step 979, training accuracy 0.98
# step 980, training accuracy 0.98
# step 981, training accuracy 0.98
# step 982, training accuracy 0.98
# step 983, training accuracy 0.98
# step 984, training accuracy 0.98
# step 985, training accuracy 0.98
# step 986, training accuracy 0.98
# step 987, training accuracy 0.98
# step 988, training accuracy 0.98
# step 989, training accuracy 0.98
# step 990, training accuracy 0.98
# step 991, training accuracy 0.98
# step 992, training accuracy 0.98
# step 993, training accuracy 0.98
# step 994, training accuracy 0.98
# step 995, training accuracy 0.98
# step 996, training accuracy 0.98
# step 997, training accuracy 0.98
# step 998, training accuracy 0.98
# step 999, training accuracy 0.98
# test accuracy 0.97

# %%
mnist.test.images.shape
# Out:
# (10000, 784)

# %%
mnist.test.labels.shape
# Out:
# (10000, 10)
