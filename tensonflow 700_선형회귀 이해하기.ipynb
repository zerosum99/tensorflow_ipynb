# %%
import tensorflow as tf

# %% [markdown]
# ## 데이터

# %%
x_data = [1,2,3]
y_data = [1,2,3]

# %% [markdown]
# ## 가중치

# %%
W = tf.Variable(tf.random_uniform([1],-1,1))

# %% [markdown]
# ## 편향

# %%
b = tf.Variable(tf.random_uniform([1],-1,1))

# %% [markdown]
# ## 실제 데이터 넣는 것 정의

# %%
X = tf.placeholder(tf.float32, name='X')

# %%
Y = tf.placeholder(tf.float32, name='Y')

# %% [markdown]
# ## 가설

# %%
hypothesis = W * X + b

# %% [markdown]
# ## 코스트 함수 설정 : 실제 차이에 대한 평균을 알아본다

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %% [markdown]
# ## 최적화를 산출한다.

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)

# %%
train_op = optimizer.minimize(cost)

# %% [markdown]
# ## 실제 실행을 한다

# %%
with tf.Session() as sess :
    sess.run(tf.global_variables_initializer()) 
    
    for step in range(100) :
        _, cost_val = sess.run([train_op, cost], feed_dict={X : x_data, Y: y_data})
        
        print(step, cost_val, sess.run(W), sess.run(b))
        
    print(sess.run(hypothesis, feed_dict={X:5}))
# Out:
# 0 4.35547 [ 1.0118618] [ 0.21343565]
# 1 0.0563383 [ 0.91541654] [ 0.16600379]
# 2 0.00477958 [ 0.92795956] [ 0.16663642]
# 3 0.00396863 [ 0.92854267] [ 0.16212529]
# 4 0.00377314 [ 0.93038607] [ 0.15828316]
# 5 0.00359383 [ 0.93204576] [ 0.1544721]
# 6 0.00342312 [ 0.93368089] [ 0.15075938]
# 7 0.00326053 [ 0.93527496] [ 0.14713515]
# 8 0.00310565 [ 0.93683094] [ 0.14359814]
# 9 0.00295813 [ 0.93834949] [ 0.14014614]
# 10 0.00281762 [ 0.9398315] [ 0.13677712]
# 11 0.00268378 [ 0.94127792] [ 0.13348909]
# 12 0.00255629 [ 0.9426896] [ 0.13028011]
# 13 0.00243487 [ 0.9440673] [ 0.12714826]
# 14 0.00231921 [ 0.94541186] [ 0.12409169]
# 15 0.00220905 [ 0.94672412] [ 0.12110861]
# 16 0.00210412 [ 0.94800484] [ 0.11819725]
# 17 0.00200416 [ 0.94925475] [ 0.11535587]
# 18 0.00190897 [ 0.95047462] [ 0.11258279]
# 19 0.0018183 [ 0.95166522] [ 0.1098764]
# 20 0.00173192 [ 0.9528271] [ 0.10723501]
# 21 0.00164965 [ 0.95396113] [ 0.10465717]
# 22 0.00157129 [ 0.95506787] [ 0.10214128]
# 23 0.00149665 [ 0.95614797] [ 0.09968586]
# 24 0.00142556 [ 0.9572022] [ 0.0972895]
# 25 0.00135785 [ 0.95823097] [ 0.09495071]
# 26 0.00129335 [ 0.95923513] [ 0.09266819]
# 27 0.00123192 [ 0.96021503] [ 0.0904405]
# 28 0.0011734 [ 0.96117151] [ 0.0882664]
# 29 0.00111766 [ 0.96210492] [ 0.08614452]
# 30 0.00106457 [ 0.96301585] [ 0.08407365]
# 31 0.001014 [ 0.96390492] [ 0.08205258]
# 32 0.000965837 [ 0.96477264] [ 0.08008011]
# 33 0.000919961 [ 0.9656195] [ 0.07815503]
# 34 0.000876259 [ 0.96644598] [ 0.07627624]
# 35 0.000834635 [ 0.96725255] [ 0.0744426]
# 36 0.000794989 [ 0.96803981] [ 0.07265306]
# 37 0.000757227 [ 0.96880805] [ 0.07090651]
# 38 0.000721263 [ 0.969558] [ 0.06920201]
# 39 0.000687002 [ 0.97028977] [ 0.06753842]
# 40 0.000654365 [ 0.97100395] [ 0.06591482]
# 41 0.000623283 [ 0.97170103] [ 0.06433028]
# 42 0.000593677 [ 0.97238129] [ 0.06278381]
